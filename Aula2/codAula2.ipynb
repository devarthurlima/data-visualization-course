# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Gráfico de pizza básico utilizando a função pie()
especie = ['Cachorro','Gato','Pássaro']
quantidade = [110,90,30]
plt.title("Proporções de espécies")
plt.pie(x=quantidade, labels=especie)
plt.show()

# %%
# 
plt.figure(figsize=(8,8))
plt.style.use
plt.title("Proporções de espécies")
plt.pie(x=quantidade, labels = especie, autopct='%1.2f%%')
plt.show()
